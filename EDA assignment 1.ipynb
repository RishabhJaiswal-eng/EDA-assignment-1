# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\rishabh jaiswal\\Downloads\\heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0

# %%
df.shape
# Out:
# (299, 13)

# %%
# first we will do the basic cleaning and pre-processing of the dataset
df.info() # as we can check that the dataset doesn't have any categorical values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    object
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 30.5+ KB

# %%
df['sex'] = df['sex'].replace({1:'male',0:'female'})

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0                    1  265000.00               1.9           130    male
# 1                    0  263358.03               1.1           136    male
# 2                    0  162000.00               1.3           129    male
# 3                    0  210000.00               1.9           137    male
# 4                    0  327000.00               2.7           116  female
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
# converting the age as integer as it cannot be a float value
df['age']=df['age'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    int32
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    object
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(2), int32(1), int64(9), object(1)
# memory usage: 29.3+ KB

# %%
#checking for null values
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# # Question
#
#
# Q.1 What is the distribution of age among heart failure patients in the dataset?

# %%
df['age'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# creating a plot for visualization
sns.countplot(data=pd.DataFrame(df['age']), x=df['age'], width=0.5)
plt.xlabel('age')
plt.ylabel('death_count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# maximum number of people aree getting heart attack at the age of 60 and maximum heart attack are ranging from 45 to 70

# %% [raw]
# # Q.2 How does the death rate vary with age?

# %%
sns.histplot(x=df['age'], data=df, palette='coolwarm')
plt.title('Relationship between Age and Death Events')
plt.xlabel('Age')
plt.ylabel('Death Event (0: No, 1: Yes)')
plt.show()
# Out:
# C:\Users\rishabh jaiswal\AppData\Local\Temp\ipykernel_10680\2968047415.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=df['age'], data=df, palette='coolwarm')

# %% [markdown]
#  Q.3 What is the percentage of male and female patients in the dataset?

# %%
gender_counts = df['sex'].value_counts()

# Calculate the total number of patients
total_patients = df.shape[0]

# Calculate the percentage of male and female patients
male_percentage = round((gender_counts['male'] / total_patients) * 100,2)
female_percentage = round((gender_counts['female'] / total_patients) * 100,2)

print(f'the male and female percantage is {male_percentage} and {female_percentage} respectively')
# Out:
# the male and female percantage is 64.88 and 35.12 respectively

# %%
# we can see it through visulaization too
percentage_data = pd.DataFrame({'gender': ['Male', 'Female'],
                                'percentage': [male_percentage, female_percentage]})

# Create a bar plot
sns.barplot(x='gender', y='percentage', data=percentage_data, width=0.3)
plt.title('Percentage of Male and Female Patients')
plt.ylabel('Percentage')
plt.xlabel('Gender')
plt.show()

# %% [markdown]
# Q.4 How does the platelate count vary among age group?

# %%
plt.scatter(df['age'], df['platelets'], color='blue')
plt.title('Platelet Count vs Age')
plt.xlabel('Age')
plt.ylabel('Platelet Count')
plt.grid(True)
plt.show()

# %% [markdown]
# Q.5 is there a correlation between  creatinine and sodium levels in the blood

# %%
# To find the correlation
df['serum_creatinine'].corr(df['serum_sodium'])
# Out:
# -0.18909521009117386

# %%
sns.regplot(x=df['serum_creatinine'], y=df['serum_sodium'], data=df)
plt.title('correlation between creatinine and sodium levels')
plt.xlabel('serum creatinine')
plt.ylabel('serum sodium')
plt.show()

# %% [markdown]
# Q.6 How does the prevalence of high blood pressure differ between male and female patients?

# %%
blood_pressure_count_male=0
blood_pressure_count_female=0
for index, row in df.iterrows():
    if row['sex']=='male' and row['high_blood_pressure']==1:
        blood_pressure_count_male += 1
    elif row['sex']=='female' and row['high_blood_pressure']==1:
        blood_pressure_count_female +=1
    else:
        pass

print(f'the prevalance of high blood pressure in male is {blood_pressure_count_male}')
print(f'the prevalance of high blood pressure in female is {blood_pressure_count_female}')
# Out:
# the prevalance of high blood pressure in male is 61
# the prevalance of high blood pressure in female is 44

# %%
sns.countplot(data=pd.DataFrame(df['high_blood_pressure']), x=df['sex'], width=0.3)
plt.title('prevalance of high blood pressure between male and female patients')
plt.xlabel('Gender')
plt.show()

# %% [markdown]
# Q.7 What is the relationship between smoking habits and the occurrence of heart failure?

# %%
sns.regplot(x=df['DEATH_EVENT'], y=df['smoking'], data=df) # here i have taken heart_faliure as death event as we don't have any heart_faliure cloumn
plt.title('relationshipe between smoking habits and occurrence of heart failure')
plt.xlabel('heart_faliure')
plt.ylabel('smoking')
plt.show()

# %% [markdown]
# as we can see there is no relationship between these two.

# %% [markdown]
# Q.8 Are there any noticeable patterns in the distribution of death events across different age groups?

# %%
sns.histplot(data=df, x=df['age'], bins=10, kde=True)
plt.title('death events across different age groups?')
plt.xlabel('Age')
plt.ylabel('death count')
plt.grid(True)
plt.show()

# %% [markdown]
# As we can see through the histogram plot that the increase in death rate starts from the age of 40 and it starts to fall rapidly after the age of 70 we can there were more deaths between the age of 50-70

# %% [markdown]
# Q.9 Is there any significant difference in ejection fraction between patients with and without diabetes

# %%
sns.countplot(data=pd.DataFrame(df['ejection_fraction']), x=df['diabetes'], width=0.3)
plt.title('difference in ejection fraction between patients with and without diabetes')
plt.xlabel('diabetes')
plt.show()

# %% [markdown]
# we can say there is a difference in the ejection fraction between the diabetic and non-diabetic patients as the ejection is more in non-diabetic patients compare to the diabitec patients

# %% [markdown]
# Q.10 How does the serum creatinine level vary between patients who survived and those who did not?

# %%
sns.barplot(data=df, y=df['serum_creatinine'], x=df['DEATH_EVENT'], width=0.3)
plt.title(' serum creatinine level vary between patients who survived and those who did not')
plt.xlabel('diabetes')
plt.show()
